# %% [markdown]
# # TFM : Aplicación de *Machine Learning* para la Gestión de Inventarios
# > Erendira Teresa Navarro García
#
# **Análisis de correlación**

# %%
# Python 3 environment Google Colab
import pandas as pd
import os
import csv
import datetime as datetime
import json 
import sklearn
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import seaborn as sns
import matplotlib.pylab as plab
from datetime import datetime
from dateutil.parser import parse
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from tabulate import tabulate
from pickle import dump
from scipy.stats import f_oneway, chi2_contingency
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
os.chdir("/content/drive/MyDrive/Files_TFM/")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Files_TFM

# %% [markdown]
# ## Lectura de datos

# %%
dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')
df_tfm = pd.read_csv('export_data_tfm.csv', parse_dates=['fecha'], date_parser=dateparse, dtype={'sku': str})
#Prepare data
df_tfm['weekday'] = df_tfm.fecha.dt.strftime('%w').astype(int)
df_tfm = df_tfm.sort_values(by='fecha').set_index('fecha')

# %%
df_tfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 51100 entries, 2019-01-02 to 2021-10-19
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sku         51100 non-null  object
#  1   bolOpen     51100 non-null  int64
#  2   bolHoliday  51100 non-null  int64
#  3   udsVenta    51100 non-null  float64
#  4   udsVentaO   51100 non-null  float64
#  5   udsStock    32900 non-null  float64
#  6   promo       51100 non-null  int64
#  7   udsVentaT   51100 non-null  float64
#  8   label       51100 non-null  int64
#  9   weekday     51100 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 4.3+ MB

# %% [markdown]
# ### Preparación de los datos

# %%
# Función para creación de nuevas variables - lag de 1 a 7 y diferencia en ventas del día anterior y del día previo
def features(dataset, columns_y):
  dataset_t = dataset.copy()
  for i in range(1,8):
    dataset_t['lag'+str(i)] = dataset_t[columns_y].shift(i)
    if i in [1,2]:
      dataset_t['diff'+str(i)] = dataset_t[columns_y].diff(i)
  # Eliminar NAs
  dataset_t = dataset_t.dropna()
  return dataset_t

# %%
results_anova = pd.DataFrame()
results_chisq = pd.DataFrame()
results_corr = pd.DataFrame()
listx = ['promo', 'promo', 'bolOpen','bolHoliday','bolHoliday','bolHoliday']
listy = ['weekday', 'bolOpen', 'weekday','promo','weekday', 'bolOpen']
columns_corr = ['udsVentaT'] + ['lag'+str(i) for i in range(1,8)] + ['diff'+str(i) for i in [1,2]]
for i in range(1,51):
  df = df_tfm[df_tfm["sku"] == str(i)]
  dataset = features(df, 'udsVentaT')
  for k in ["promo","weekday","bolOpen","bolHoliday"]:
    cat_vs_num=dataset.groupby(k)['udsVentaT'].apply(list)
    AnovaResults = f_oneway(*cat_vs_num)
    print(str(i),k,'P-Value for Anova is: ', AnovaResults[1])
    k_vs = k + ' vs udsVentaT'
    tab = pd.DataFrame({"sku":[str(i)],"prueba":[k_vs], "pValue":[AnovaResults[1]]})
    results_anova = results_anova.append(tab,ignore_index=True) 
  for x, y in zip(listx, listy):
    Crosst=pd.crosstab(index=dataset[x],columns=dataset[y])
    print(Crosst)
    ChiSqR = chi2_contingency(Crosst)
    print(str(i),x,y,'The P-Value of the ChiSq Test is:', ChiSqR[1])
    x_vs_y = x + ' vs ' + y
    tabc = pd.DataFrame({"sku":[str(i)],"prueba":[x_vs_y], "pValue":[ChiSqR[1]]})
    results_chisq = results_chisq.append(tabc,ignore_index=True)
  #Correlación Pearson 
  plt.figure(figsize=(12,10))
  cor = dataset[columns_corr].corr()
  sns_plot = sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
  plt.title("SKU" + str(i))
  plt.savefig("corr_sku_" + str(i) + ".png", dpi=300, bbox_inches='tight')
  plt.close()
  cor["sku"] = str(i)
  results_corr = results_corr.append(cor.reset_index(),ignore_index=True)
# Out:
# 1 promo P-Value for Anova is:  0.8993999844488696
# 1 weekday P-Value for Anova is:  9.150991617656698e-33
# 1 bolOpen P-Value for Anova is:  3.7839531734113903e-41
# 1 bolHoliday P-Value for Anova is:  5.4234292635997765e-43
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 1 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        52  332
# 1        51  223
# 1 promo bolOpen The P-Value of the ChiSq Test is: 0.09770312630882257
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   4   1   3   1   6   3
# 1         9  90  93  91  93  88  91
# 1 bolOpen weekday The P-Value of the ChiSq Test is: 1.9189480866985953e-97
# promo         0    1
# bolHoliday
# 0           331  219
# 1            53   55
# 1 bolHoliday promo The P-Value of the ChiSq Test is: 0.04193924740884467
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  89  92  91  93  88  90
# 1           87   5   2   3   1   6   4
# 1 bolHoliday weekday The P-Value of the ChiSq Test is: 3.2557551920812554e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           100    8
# 1 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.7318154159327416e-126
# 2 promo P-Value for Anova is:  0.03947387411937296
# 2 weekday P-Value for Anova is:  7.016050312863717e-40
# 2 bolOpen P-Value for Anova is:  1.59187665553421e-48
# 2 bolHoliday P-Value for Anova is:  1.9631893938744656e-51
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 2 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        53  331
# 1        50  224
# 2 promo bolOpen The P-Value of the ChiSq Test is: 0.15030492465788203
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   6   1   3   1   4   3
# 1         9  88  93  91  93  90  91
# 2 bolOpen weekday The P-Value of the ChiSq Test is: 1.9189480866985953e-97
# promo         0    1
# bolHoliday
# 0           330  220
# 1            54   54
# 2 bolHoliday promo The P-Value of the ChiSq Test is: 0.06866477429895995
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  87  92  91  93  90  90
# 1           87   7   2   3   1   4   4
# 2 bolHoliday weekday The P-Value of the ChiSq Test is: 2.791749974823376e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           100    8
# 2 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.7318154159327416e-126
# 3 promo P-Value for Anova is:  0.12388037391299826
# 3 weekday P-Value for Anova is:  7.926511419026284e-24
# 3 bolOpen P-Value for Anova is:  5.223788356515084e-25
# 3 bolHoliday P-Value for Anova is:  4.6700694100040973e-26
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 3 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        51  333
# 1        47  227
# 3 promo bolOpen The P-Value of the ChiSq Test is: 0.20615716670888382
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        83   1   3   2   1   5   3
# 1        11  93  91  92  93  89  91
# 3 bolOpen weekday The P-Value of the ChiSq Test is: 9.999462363114776e-98
# promo         0    1
# bolHoliday
# 0           330  218
# 1            54   56
# 3 bolHoliday promo The P-Value of the ChiSq Test is: 0.03991273977152072
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  91  92  92  89  90
# 1           88   6   3   2   2   5   4
# 3 bolHoliday weekday The P-Value of the ChiSq Test is: 1.1744439152316264e-97
# bolOpen      0    1
# bolHoliday
# 0            2  546
# 1           96   14
# 3 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.032463189882357e-119
# 4 promo P-Value for Anova is:  0.5169807151070935
# 4 weekday P-Value for Anova is:  4.676928962983556e-30
# 4 bolOpen P-Value for Anova is:  8.115143036284747e-34
# 4 bolHoliday P-Value for Anova is:  1.626441967821647e-34
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 4 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        51  333
# 1        48  226
# 4 promo bolOpen The P-Value of the ChiSq Test is: 0.16513318277005676
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   1   3   4   1   4   1
# 1         9  93  91  90  93  90  93
# 4 bolOpen weekday The P-Value of the ChiSq Test is: 2.5705639225472742e-102
# promo         0    1
# bolHoliday
# 0           330  219
# 1            54   55
# 4 bolHoliday promo The P-Value of the ChiSq Test is: 0.05261884180596141
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  91  90  92  90  92
# 1           88   6   3   4   2   4   2
# 4 bolHoliday weekday The P-Value of the ChiSq Test is: 9.186836903277314e-99
# bolOpen      0    1
# bolHoliday
# 0            2  547
# 1           97   12
# 4 bolHoliday bolOpen The P-Value of the ChiSq Test is: 4.738810541085556e-122
# 5 promo P-Value for Anova is:  0.6840196056212515
# 5 weekday P-Value for Anova is:  1.0439426257283833e-28
# 5 bolOpen P-Value for Anova is:  1.48235579303328e-36
# 5 bolHoliday P-Value for Anova is:  3.697206130397328e-38
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 5 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        52  332
# 1        52  222
# 5 promo bolOpen The P-Value of the ChiSq Test is: 0.07571480614533439
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        86   5   2   3   1   4   3
# 1         8  89  92  91  93  90  91
# 5 bolOpen weekday The P-Value of the ChiSq Test is: 5.909627241842805e-99
# promo         0    1
# bolHoliday
# 0           331  219
# 1            53   55
# 5 bolHoliday promo The P-Value of the ChiSq Test is: 0.04193924740884467
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  91  91  93  90  90
# 1           87   6   3   3   1   4   4
# 5 bolHoliday weekday The P-Value of the ChiSq Test is: 3.7968774444961455e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           101    7
# 5 bolHoliday bolOpen The P-Value of the ChiSq Test is: 5.014383281530817e-128
# 6 promo P-Value for Anova is:  2.7937280229572593e-16
# 6 weekday P-Value for Anova is:  1.5861511663718297e-30
# 6 bolOpen P-Value for Anova is:  5.3542304928614215e-37
# 6 bolHoliday P-Value for Anova is:  3.714895497464787e-38
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 6 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        53  331
# 1        47  227
# 6 promo bolOpen The P-Value of the ChiSq Test is: 0.2844930943686322
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        86   1   2   4   2   4   1
# 1         8  93  92  90  92  90  93
# 6 bolOpen weekday The P-Value of the ChiSq Test is: 5.973094632322571e-104
# promo         0    1
# bolHoliday
# 0           328  221
# 1            56   53
# 6 bolHoliday promo The P-Value of the ChiSq Test is: 0.13037989451598828
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  92  90  91  90  92
# 1           88   6   2   4   3   4   2
# 6 bolHoliday weekday The P-Value of the ChiSq Test is: 9.186836903277314e-99
# bolOpen      0    1
# bolHoliday
# 0            2  547
# 1           98   11
# 6 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.4778809041788716e-123
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:3347: RuntimeWarning:
#
# invalid value encountered in double_scalars
# 7 promo P-Value for Anova is:  nan
# 7 weekday P-Value for Anova is:  3.0275216474212584e-57
# 7 bolOpen P-Value for Anova is:  6.3446620086665995e-59
# 7 bolHoliday P-Value for Anova is:  1.343408476957277e-65
# weekday   0   1   2   3   4   5   6
# promo
# 0        94  94  94  94  94  94  94
# 7 promo weekday The P-Value of the ChiSq Test is: 1.0
# bolOpen   0    1
# promo
# 0        99  559
# 7 promo bolOpen The P-Value of the ChiSq Test is: 1.0
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        83   2   2   4   2   4   2
# 1        11  92  92  90  92  90  92
# 7 bolOpen weekday The P-Value of the ChiSq Test is: 2.290398241366141e-96
# promo         0
# bolHoliday
# 0           548
# 1           110
# 7 bolHoliday promo The P-Value of the ChiSq Test is: 1.0
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  90  92  89  92  88  91
# 1           88   4   2   5   2   6   3
# 7 bolHoliday weekday The P-Value of the ChiSq Test is: 1.1744439152316597e-97
# bolOpen      0    1
# bolHoliday
# 0            2  546
# 1           97   13
# 7 bolHoliday bolOpen The P-Value of the ChiSq Test is: 9.94223390761412e-121
# 8 promo P-Value for Anova is:  6.350230067917399e-06
# 8 weekday P-Value for Anova is:  8.958059087593246e-20
# 8 bolOpen P-Value for Anova is:  1.832341972627453e-24
# 8 bolHoliday P-Value for Anova is:  1.204831587375138e-24
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 8 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        64  297
# 1        41  256
# 8 promo bolOpen The P-Value of the ChiSq Test is: 0.20739607299057186
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        89   5   2   2   1   5   1
# 1         5  89  92  92  93  89  93
# 8 bolOpen weekday The P-Value of the ChiSq Test is: 1.4716538428470416e-106
# promo         0    1
# bolHoliday
# 0           295  255
# 1            66   42
# 8 bolHoliday promo The P-Value of the ChiSq Test is: 0.18636693804264026
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  88  92
# 1           88   7   2   2   1   6   2
# 8 bolHoliday weekday The P-Value of the ChiSq Test is: 2.9785078141445735e-100
# bolOpen       0    1
# bolHoliday
# 0             2  548
# 1           103    5
# 8 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.2897090329570751e-132
# 9 promo P-Value for Anova is:  0.9839886818359959
# 9 weekday P-Value for Anova is:  7.452588308184929e-21
# 9 bolOpen P-Value for Anova is:  2.0017145837732973e-21
# 9 bolHoliday P-Value for Anova is:  4.253940188422519e-27
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 9 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        39  362
# 1        33  224
# 9 promo bolOpen The P-Value of the ChiSq Test is: 0.2624012661664352
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   4   1
# 1        35  91  92  92  93  90  93
# 9 bolOpen weekday The P-Value of the ChiSq Test is: 1.8737776208232032e-62
# promo         0    1
# bolHoliday
# 0           342  209
# 1            59   48
# 9 bolHoliday promo The P-Value of the ChiSq Test is: 0.2164441517646767
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  92  92  93  89  91
# 1           88   6   2   2   1   5   3
# 9 bolHoliday weekday The P-Value of the ChiSq Test is: 3.17710868016279e-101
# bolOpen      0    1
# bolHoliday
# 0            2  549
# 1           70   37
# 9 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.5331795859033784e-85
# 10 promo P-Value for Anova is:  0.0035227636857990325
# 10 weekday P-Value for Anova is:  6.1864631018632254e-21
# 10 bolOpen P-Value for Anova is:  2.5316068846676876e-23
# 10 bolHoliday P-Value for Anova is:  1.6775955975572495e-24
# weekday   0   1   2   3   4   5   6
# promo
# 0        47  48  46  46  45  47  47
# 1        47  46  48  48  49  47  47
# 10 promo weekday The P-Value of the ChiSq Test is: 0.9997264315844906
# bolOpen   0    1
# promo
# 0        35  291
# 1        37  295
# 10 promo bolOpen The P-Value of the ChiSq Test is: 0.9657858785433745
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   3   2
# 1        35  91  92  92  93  91  92
# 10 bolOpen weekday The P-Value of the ChiSq Test is: 2.324317102385867e-62
# promo         0    1
# bolHoliday
# 0           273  277
# 1            53   55
# 10 bolHoliday promo The P-Value of the ChiSq Test is: 0.9987237029569834
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  90  90
# 1           88   7   2   2   1   4   4
# 10 bolHoliday weekday The P-Value of the ChiSq Test is: 4.0511838731624033e-100
# bolOpen      0    1
# bolHoliday
# 0            2  548
# 1           70   38
# 10 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.033608840423082e-84
# 11 promo P-Value for Anova is:  0.26888736782947875
# 11 weekday P-Value for Anova is:  6.03656786256283e-26
# 11 bolOpen P-Value for Anova is:  6.33712834383343e-19
# 11 bolHoliday P-Value for Anova is:  2.123599709920694e-23
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 11 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        45  316
# 1        27  270
# 11 promo bolOpen The P-Value of the ChiSq Test is: 0.20970306064422842
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   4   1
# 1        35  91  92  92  93  90  93
# 11 bolOpen weekday The P-Value of the ChiSq Test is: 1.8737776208232032e-62
# promo         0    1
# bolHoliday
# 0           296  255
# 1            65   42
# 11 bolHoliday promo The P-Value of the ChiSq Test is: 0.2184966689447956
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  92  92  93  89  91
# 1           88   6   2   2   1   5   3
# 11 bolHoliday weekday The P-Value of the ChiSq Test is: 3.17710868016279e-101
# bolOpen      0    1
# bolHoliday
# 0            2  549
# 1           70   37
# 11 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.5331795859033784e-85
# 12 promo P-Value for Anova is:  0.6700888325247445
# 12 weekday P-Value for Anova is:  0.0020083429821364488
# 12 bolOpen P-Value for Anova is:  nan
# 12 bolHoliday P-Value for Anova is:  nan
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  52  52  52  53  53  53
# 1        41  42  42  42  41  41  41
# 12 promo weekday The P-Value of the ChiSq Test is: 0.9999917926268256
# bolOpen    1
# promo
# 0        368
# 1        290
# 12 promo bolOpen The P-Value of the ChiSq Test is: 1.0
# weekday   0   1   2   3   4   5   6
# bolOpen
# 1        94  94  94  94  94  94  94
# 12 bolOpen weekday The P-Value of the ChiSq Test is: 1.0
# promo         0    1
# bolHoliday
# 0           368  290
# 12 bolHoliday promo The P-Value of the ChiSq Test is: 1.0
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0           94  94  94  94  94  94  94
# 12 bolHoliday weekday The P-Value of the ChiSq Test is: 1.0
# bolOpen       1
# bolHoliday
# 0           658
# 12 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.0
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:3347: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:3347: RuntimeWarning:
#
# invalid value encountered in double_scalars
# 13 promo P-Value for Anova is:  nan
# 13 weekday P-Value for Anova is:  7.394971026012023e-33
# 13 bolOpen P-Value for Anova is:  7.373921575491074e-40
# 13 bolHoliday P-Value for Anova is:  5.7087249509574314e-40
# weekday   0   1   2   3   4   5   6
# promo
# 0        94  94  94  94  94  94  94
# 13 promo weekday The P-Value of the ChiSq Test is: 1.0
# bolOpen    0    1
# promo
# 0        100  558
# 13 promo bolOpen The P-Value of the ChiSq Test is: 1.0
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        86   1   2   4   2   4   1
# 1         8  93  92  90  92  90  93
# 13 bolOpen weekday The P-Value of the ChiSq Test is: 5.973094632322571e-104
# promo         0
# bolHoliday
# 0           549
# 1           109
# 13 bolHoliday promo The P-Value of the ChiSq Test is: 1.0
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  92  90  91  90  92
# 1           88   6   2   4   3   4   2
# 13 bolHoliday weekday The P-Value of the ChiSq Test is: 9.186836903277314e-99
# bolOpen      0    1
# bolHoliday
# 0            2  547
# 1           98   11
# 13 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.4778809041788716e-123
# 14 promo P-Value for Anova is:  0.9293709507766967
# 14 weekday P-Value for Anova is:  4.607178050448608e-20
# 14 bolOpen P-Value for Anova is:  6.183249769562584e-25
# 14 bolHoliday P-Value for Anova is:  2.493797318495533e-24
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 14 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        58  303
# 1        44  253
# 14 promo bolOpen The P-Value of the ChiSq Test is: 0.7389554666564275
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        84   3   3   4   1   4   3
# 1        10  91  91  90  93  90  91
# 14 bolOpen weekday The P-Value of the ChiSq Test is: 1.3633526925774508e-95
# promo         0    1
# bolHoliday
# 0           299  251
# 1            62   46
# 14 bolHoliday promo The P-Value of the ChiSq Test is: 0.6345043163689585
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  90  90  90  93  90  90
# 1           87   4   4   4   1   4   4
# 14 bolHoliday weekday The P-Value of the ChiSq Test is: 4.781763747247504e-97
# bolOpen      0    1
# bolHoliday
# 0            3  547
# 1           99    9
# 14 bolHoliday bolOpen The P-Value of the ChiSq Test is: 5.905313392770232e-125
# 15 promo P-Value for Anova is:  1.1992870898464288e-18
# 15 weekday P-Value for Anova is:  1.7802102098355333e-16
# 15 bolOpen P-Value for Anova is:  6.509181291278081e-19
# 15 bolHoliday P-Value for Anova is:  1.80898246548747e-18
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 15 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        53  331
# 1        52  222
# 15 promo bolOpen The P-Value of the ChiSq Test is: 0.09309210943018026
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        89   5   2   2   1   5   1
# 1         5  89  92  92  93  89  93
# 15 bolOpen weekday The P-Value of the ChiSq Test is: 1.4716538428470416e-106
# promo         0    1
# bolHoliday
# 0           331  219
# 1            53   55
# 15 bolHoliday promo The P-Value of the ChiSq Test is: 0.04193924740884467
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  88  92
# 1           88   7   2   2   1   6   2
# 15 bolHoliday weekday The P-Value of the ChiSq Test is: 2.9785078141445735e-100
# bolOpen       0    1
# bolHoliday
# 0             2  548
# 1           103    5
# 15 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.2897090329570751e-132
# 16 promo P-Value for Anova is:  4.650501622764279e-13
# 16 weekday P-Value for Anova is:  8.814082092210191e-23
# 16 bolOpen P-Value for Anova is:  1.0691460496110107e-28
# 16 bolHoliday P-Value for Anova is:  7.7056093219058e-30
# weekday   0   1   2   3   4   5   6
# promo
# 0        76  74  73  73  75  76  76
# 1        18  20  21  21  19  18  18
# 16 promo weekday The P-Value of the ChiSq Test is: 0.9934546411020053
# bolOpen   0    1
# promo
# 0        85  438
# 1        18  117
# 16 promo bolOpen The P-Value of the ChiSq Test is: 0.484350005351051
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   4   1   3   1   6   3
# 1         9  90  93  91  93  88  91
# 16 bolOpen weekday The P-Value of the ChiSq Test is: 1.9189480866985953e-97
# promo         0    1
# bolHoliday
# 0           433  117
# 1            90   18
# 16 bolHoliday promo The P-Value of the ChiSq Test is: 0.3403841744268393
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  89  92  91  93  88  90
# 1           87   5   2   3   1   6   4
# 16 bolHoliday weekday The P-Value of the ChiSq Test is: 3.2557551920812554e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           100    8
# 16 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.7318154159327416e-126
# 17 promo P-Value for Anova is:  1.0601638790354685e-05
# 17 weekday P-Value for Anova is:  2.230729678950463e-14
# 17 bolOpen P-Value for Anova is:  1.2287521977977267e-19
# 17 bolHoliday P-Value for Anova is:  9.589367501082027e-21
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 17 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        54  330
# 1        47  227
# 17 promo bolOpen The P-Value of the ChiSq Test is: 0.32977410674143715
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   3   2   3   1   4   3
# 1         9  91  92  91  93  90  91
# 17 bolOpen weekday The P-Value of the ChiSq Test is: 1.147677668171279e-99
# promo         0    1
# bolHoliday
# 0           330  221
# 1            54   53
# 17 bolHoliday promo The P-Value of the ChiSq Test is: 0.0886838948867039
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  89  91  91  93  90  90
# 1           87   5   3   3   1   4   4
# 17 bolHoliday weekday The P-Value of the ChiSq Test is: 3.136736575531036e-98
# bolOpen      0    1
# bolHoliday
# 0            3  548
# 1           98    9
# 17 bolHoliday bolOpen The P-Value of the ChiSq Test is: 8.34304772070663e-125
# 18 promo P-Value for Anova is:  0.5734258352016441
# 18 weekday P-Value for Anova is:  6.13256182639349e-18
# 18 bolOpen P-Value for Anova is:  8.656845458673654e-23
# 18 bolHoliday P-Value for Anova is:  1.8042316932165105e-22
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 18 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        62  299
# 1        41  256
# 18 promo bolOpen The P-Value of the ChiSq Test is: 0.28191961705806257
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   4   1   3   1   6   3
# 1         9  90  93  91  93  88  91
# 18 bolOpen weekday The P-Value of the ChiSq Test is: 1.9189480866985953e-97
# promo         0    1
# bolHoliday
# 0           296  254
# 1            65   43
# 18 bolHoliday promo The P-Value of the ChiSq Test is: 0.26704143141540115
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  89  92  91  93  88  90
# 1           87   5   2   3   1   6   4
# 18 bolHoliday weekday The P-Value of the ChiSq Test is: 3.2557551920812554e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           100    8
# 18 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.7318154159327416e-126
# 19 promo P-Value for Anova is:  0.3845061757479392
# 19 weekday P-Value for Anova is:  3.1110115965040097e-22
# 19 bolOpen P-Value for Anova is:  5.14324936418667e-23
# 19 bolHoliday P-Value for Anova is:  1.013840695431828e-27
# weekday   0   1   2   3   4   5   6
# promo
# 0        47  48  46  46  45  47  47
# 1        47  46  48  48  49  47  47
# 19 promo weekday The P-Value of the ChiSq Test is: 0.9997264315844906
# bolOpen   0    1
# promo
# 0        35  291
# 1        37  295
# 19 promo bolOpen The P-Value of the ChiSq Test is: 0.9657858785433745
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   4   1
# 1        35  91  92  92  93  90  93
# 19 bolOpen weekday The P-Value of the ChiSq Test is: 1.8737776208232032e-62
# promo         0    1
# bolHoliday
# 0           274  277
# 1            52   55
# 19 bolHoliday promo The P-Value of the ChiSq Test is: 0.9138231989213831
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  92  92  93  89  91
# 1           88   6   2   2   1   5   3
# 19 bolHoliday weekday The P-Value of the ChiSq Test is: 3.17710868016279e-101
# bolOpen      0    1
# bolHoliday
# 0            2  549
# 1           70   37
# 19 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.5331795859033784e-85
# 20 promo P-Value for Anova is:  0.09014780736994688
# 20 weekday P-Value for Anova is:  3.8663255928207225e-19
# 20 bolOpen P-Value for Anova is:  8.204748905213948e-25
# 20 bolHoliday P-Value for Anova is:  2.9477763671170816e-24
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 20 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        60  341
# 1        45  212
# 20 promo bolOpen The P-Value of the ChiSq Test is: 0.4464433167603741
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        90   4   2   2   1   4   2
# 1         4  90  92  92  93  90  92
# 20 bolOpen weekday The P-Value of the ChiSq Test is: 2.3160469652466343e-109
# promo         0    1
# bolHoliday
# 0           344  210
# 1            57   47
# 20 bolHoliday promo The P-Value of the ChiSq Test is: 0.1977609187977081
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  89  92  92  93  90  91
# 1           87   5   2   2   1   4   3
# 20 bolHoliday weekday The P-Value of the ChiSq Test is: 7.575359012285561e-102
# bolOpen       0    1
# bolHoliday
# 0             3  551
# 1           102    2
# 20 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.607701502361466e-135
# 21 promo P-Value for Anova is:  0.07133684591078114
# 21 weekday P-Value for Anova is:  5.06314889958546e-19
# 21 bolOpen P-Value for Anova is:  4.5456580098345515e-25
# 21 bolHoliday P-Value for Anova is:  2.4584554567111312e-23
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 21 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        60  341
# 1        47  210
# 21 promo bolOpen The P-Value of the ChiSq Test is: 0.3079648802659526
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        90   5   3   3   1   4   1
# 1         4  89  91  91  93  90  93
# 21 bolOpen weekday The P-Value of the ChiSq Test is: 6.5165650530219e-107
# promo         0    1
# bolHoliday
# 0           344  208
# 1            57   49
# 21 bolHoliday promo The P-Value of the ChiSq Test is: 0.12283450981541383
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  91  91  93  90  92
# 1           87   6   3   3   1   4   2
# 21 bolHoliday weekday The P-Value of the ChiSq Test is: 1.693862687693574e-99
# bolOpen       0    1
# bolHoliday
# 0             3  549
# 1           104    2
# 21 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.1552670736956414e-135
# 22 promo P-Value for Anova is:  0.18231545898139606
# 22 weekday P-Value for Anova is:  4.4019747680340894e-16
# 22 bolOpen P-Value for Anova is:  8.179493752181981e-16
# 22 bolHoliday P-Value for Anova is:  1.7857370130413706e-19
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 22 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        38  363
# 1        33  224
# 22 promo bolOpen The P-Value of the ChiSq Test is: 0.21936147614122078
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   3   1
# 1        35  91  92  92  93  91  93
# 22 bolOpen weekday The P-Value of the ChiSq Test is: 1.4197753646033676e-63
# promo         0    1
# bolHoliday
# 0           343  209
# 1            58   48
# 22 bolHoliday promo The P-Value of the ChiSq Test is: 0.18496373759017504
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  89  91  91  93  90  92
# 1           88   5   3   3   1   4   2
# 22 bolHoliday weekday The P-Value of the ChiSq Test is: 2.8100025986200162e-102
# bolOpen      0    1
# bolHoliday
# 0            2  550
# 1           69   37
# 22 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.0207706142350735e-84
# 23 promo P-Value for Anova is:  0.13008108145122954
# 23 weekday P-Value for Anova is:  6.341275434708446e-18
# 23 bolOpen P-Value for Anova is:  1.0972537307991112e-16
# 23 bolHoliday P-Value for Anova is:  1.5042602782786662e-18
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 23 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        38  363
# 1        34  223
# 23 promo bolOpen The P-Value of the ChiSq Test is: 0.16860463359535943
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   3   2
# 1        35  91  92  92  93  91  92
# 23 bolOpen weekday The P-Value of the ChiSq Test is: 2.324317102385867e-62
# promo         0    1
# bolHoliday
# 0           344  206
# 1            57   51
# 23 bolHoliday promo The P-Value of the ChiSq Test is: 0.07275780626104889
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  90  90
# 1           88   7   2   2   1   4   4
# 23 bolHoliday weekday The P-Value of the ChiSq Test is: 4.0511838731624033e-100
# bolOpen      0    1
# bolHoliday
# 0            2  548
# 1           70   38
# 23 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.033608840423082e-84
# 24 promo P-Value for Anova is:  8.018857223630118e-13
# 24 weekday P-Value for Anova is:  1.156162052176263e-17
# 24 bolOpen P-Value for Anova is:  7.618447088996262e-19
# 24 bolHoliday P-Value for Anova is:  1.7164850726955546e-20
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 24 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        33  351
# 1        39  235
# 24 promo bolOpen The P-Value of the ChiSq Test is: 0.030935105619855182
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   3   2
# 1        35  91  92  92  93  91  92
# 24 bolOpen weekday The P-Value of the ChiSq Test is: 2.324317102385867e-62
# promo         0    1
# bolHoliday
# 0           332  218
# 1            52   56
# 24 bolHoliday promo The P-Value of the ChiSq Test is: 0.02460005778183108
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  90  90
# 1           88   7   2   2   1   4   4
# 24 bolHoliday weekday The P-Value of the ChiSq Test is: 4.0511838731624033e-100
# bolOpen      0    1
# bolHoliday
# 0            2  548
# 1           70   38
# 24 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.033608840423082e-84
# 25 promo P-Value for Anova is:  0.5798298621020823
# 25 weekday P-Value for Anova is:  0.05971548028573856
# 25 bolOpen P-Value for Anova is:  nan
# 25 bolHoliday P-Value for Anova is:  nan
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  52  52  52  53  53  53
# 1        41  42  42  42  41  41  41
# 25 promo weekday The P-Value of the ChiSq Test is: 0.9999917926268256
# bolOpen    1
# promo
# 0        368
# 1        290
# 25 promo bolOpen The P-Value of the ChiSq Test is: 1.0
# weekday   0   1   2   3   4   5   6
# bolOpen
# 1        94  94  94  94  94  94  94
# 25 bolOpen weekday The P-Value of the ChiSq Test is: 1.0
# promo         0    1
# bolHoliday
# 0           368  290
# 25 bolHoliday promo The P-Value of the ChiSq Test is: 1.0
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0           94  94  94  94  94  94  94
# 25 bolHoliday weekday The P-Value of the ChiSq Test is: 1.0
# bolOpen       1
# bolHoliday
# 0           658
# 25 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.0
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:3347: RuntimeWarning:
#
# invalid value encountered in double_scalars
# 26 promo P-Value for Anova is:  1.3530688470737282e-07
# 26 weekday P-Value for Anova is:  3.319527196806458e-13
# 26 bolOpen P-Value for Anova is:  3.407244104753256e-17
# 26 bolHoliday P-Value for Anova is:  1.600651923650527e-17
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 26 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        52  332
# 1        46  228
# 26 promo bolOpen The P-Value of the ChiSq Test is: 0.2973739556492217
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   2   3   2   0   5   1
# 1         9  92  91  92  94  89  93
# 26 bolOpen weekday The P-Value of the ChiSq Test is: 1.085410499195868e-103
# promo         0    1
# bolHoliday
# 0           329  221
# 1            55   53
# 26 bolHoliday promo The P-Value of the ChiSq Test is: 0.10802897774540106
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  91  92  93  89  92
# 1           88   7   3   2   1   5   2
# 26 bolHoliday weekday The P-Value of the ChiSq Test is: 3.7513387919290853e-100
# bolOpen      0    1
# bolHoliday
# 0            2  548
# 1           96   12
# 26 bolHoliday bolOpen The P-Value of the ChiSq Test is: 7.026130725383532e-122
# 27 promo P-Value for Anova is:  0.001931812248356206
# 27 weekday P-Value for Anova is:  1.1758032129430268e-20
# 27 bolOpen P-Value for Anova is:  6.064302557344718e-25
# 27 bolHoliday P-Value for Anova is:  2.527880346220182e-23
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 27 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        64  297
# 1        43  254
# 27 promo bolOpen The P-Value of the ChiSq Test is: 0.3085636094275728
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        90   5   2   2   1   5   2
# 1         4  89  92  92  93  89  92
# 27 bolOpen weekday The P-Value of the ChiSq Test is: 6.030519492794265e-107
# promo         0    1
# bolHoliday
# 0           297  255
# 1            64   42
# 27 bolHoliday promo The P-Value of the ChiSq Test is: 0.2546951755239689
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  92  92  93  89  91
# 1           87   6   2   2   1   5   3
# 27 bolHoliday weekday The P-Value of the ChiSq Test is: 1.4490272802898155e-99
# bolOpen       0    1
# bolHoliday
# 0             3  549
# 1           104    2
# 27 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.1552670736956414e-135
# 28 promo P-Value for Anova is:  0.561334116013738
# 28 weekday P-Value for Anova is:  3.2410789753179173e-19
# 28 bolOpen P-Value for Anova is:  4.528811554627822e-25
# 28 bolHoliday P-Value for Anova is:  1.2736034163014184e-24
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 28 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        63  298
# 1        41  256
# 28 promo bolOpen The P-Value of the ChiSq Test is: 0.24251275837627861
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        86   5   2   3   1   4   3
# 1         8  89  92  91  93  90  91
# 28 bolOpen weekday The P-Value of the ChiSq Test is: 5.909627241842805e-99
# promo         0    1
# bolHoliday
# 0           296  254
# 1            65   43
# 28 bolHoliday promo The P-Value of the ChiSq Test is: 0.26704143141540115
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  91  91  93  90  90
# 1           87   6   3   3   1   4   4
# 28 bolHoliday weekday The P-Value of the ChiSq Test is: 3.7968774444961455e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           101    7
# 28 bolHoliday bolOpen The P-Value of the ChiSq Test is: 5.014383281530817e-128
# 29 promo P-Value for Anova is:  0.2352131835369771
# 29 weekday P-Value for Anova is:  5.055389544381204e-27
# 29 bolOpen P-Value for Anova is:  3.173619379506971e-33
# 29 bolHoliday P-Value for Anova is:  7.159819290967608e-35
# weekday   0   1   2   3   4   5   6
# promo
# 0        21  22  23  23  20  20  21
# 1        73  72  71  71  74  74  73
# 29 promo weekday The P-Value of the ChiSq Test is: 0.9966101430769535
# bolOpen   0    1
# promo
# 0        16  134
# 1        88  420
# 29 promo bolOpen The P-Value of the ChiSq Test is: 0.06632992623803716
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        86   5   2   3   1   4   3
# 1         8  89  92  91  93  90  91
# 29 bolOpen weekday The P-Value of the ChiSq Test is: 5.909627241842805e-99
# promo         0    1
# bolHoliday
# 0           135  415
# 1            15   93
# 29 bolHoliday promo The P-Value of the ChiSq Test is: 0.022134500709257352
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  91  91  93  90  90
# 1           87   6   3   3   1   4   4
# 29 bolHoliday weekday The P-Value of the ChiSq Test is: 3.7968774444961455e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           101    7
# 29 bolHoliday bolOpen The P-Value of the ChiSq Test is: 5.014383281530817e-128
# 30 promo P-Value for Anova is:  0.0007786325806245349
# 30 weekday P-Value for Anova is:  1.3729837517108137e-19
# 30 bolOpen P-Value for Anova is:  nan
# 30 bolHoliday P-Value for Anova is:  nan
# weekday   0   1   2   3   4   5   6
# promo
# 0        63  63  63  63  64  63  63
# 1        31  31  31  31  30  31  31
# 30 promo weekday The P-Value of the ChiSq Test is: 0.9999985494558818
# bolOpen    1
# promo
# 0        442
# 1        216
# 30 promo bolOpen The P-Value of the ChiSq Test is: 1.0
# weekday   0   1   2   3   4   5   6
# bolOpen
# 1        94  94  94  94  94  94  94
# 30 bolOpen weekday The P-Value of the ChiSq Test is: 1.0
# promo         0    1
# bolHoliday
# 0           442  216
# 30 bolHoliday promo The P-Value of the ChiSq Test is: 1.0
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0           94  94  94  94  94  94  94
# 30 bolHoliday weekday The P-Value of the ChiSq Test is: 1.0
# bolOpen       1
# bolHoliday
# 0           658
# 30 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.0
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:3347: RuntimeWarning:
#
# invalid value encountered in double_scalars
# 31 promo P-Value for Anova is:  0.4453786348354444
# 31 weekday P-Value for Anova is:  4.352780585502679e-30
# 31 bolOpen P-Value for Anova is:  1.3585816226229863e-34
# 31 bolHoliday P-Value for Anova is:  4.665222120030123e-36
# weekday   0   1   2   3   4   5   6
# promo
# 0        21  22  23  23  20  20  21
# 1        73  72  71  71  74  74  73
# 31 promo weekday The P-Value of the ChiSq Test is: 0.9966101430769535
# bolOpen   0    1
# promo
# 0        18  132
# 1        82  426
# 31 promo bolOpen The P-Value of the ChiSq Test is: 0.26609479410152015
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        86   1   2   4   2   4   1
# 1         8  93  92  90  92  90  93
# 31 bolOpen weekday The P-Value of the ChiSq Test is: 5.973094632322571e-104
# promo         0    1
# bolHoliday
# 0           134  415
# 1            16   93
# 31 bolHoliday promo The P-Value of the ChiSq Test is: 0.0369215098796428
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  92  90  91  90  92
# 1           88   6   2   4   3   4   2
# 31 bolHoliday weekday The P-Value of the ChiSq Test is: 9.186836903277314e-99
# bolOpen      0    1
# bolHoliday
# 0            2  547
# 1           98   11
# 31 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.4778809041788716e-123
# 32 promo P-Value for Anova is:  0.02258719717894985
# 32 weekday P-Value for Anova is:  1.1561408771343018e-38
# 32 bolOpen P-Value for Anova is:  7.226678011691772e-32
# 32 bolHoliday P-Value for Anova is:  9.102194770590436e-45
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  55  53  52  51  52  53
# 1        41  39  41  42  43  42  41
# 32 promo weekday The P-Value of the ChiSq Test is: 0.9987913111676995
# bolOpen   0    1
# promo
# 0        34  335
# 1        37  252
# 32 promo bolOpen The P-Value of the ChiSq Test is: 0.17832514358424822
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   3   1
# 1        35  91  92  92  93  91  93
# 32 bolOpen weekday The P-Value of the ChiSq Test is: 1.4197753646033676e-63
# promo         0    1
# bolHoliday
# 0           312  240
# 1            57   49
# 32 bolHoliday promo The P-Value of the ChiSq Test is: 0.6778964133028538
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  89  91  91  93  90  92
# 1           88   5   3   3   1   4   2
# 32 bolHoliday weekday The P-Value of the ChiSq Test is: 2.8100025986200162e-102
# bolOpen      0    1
# bolHoliday
# 0            2  550
# 1           69   37
# 32 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.0207706142350735e-84
# 33 promo P-Value for Anova is:  0.9319784543545558
# 33 weekday P-Value for Anova is:  4.517454970611545e-27
# 33 bolOpen P-Value for Anova is:  1.0766448372552419e-23
# 33 bolHoliday P-Value for Anova is:  2.143843824004265e-25
# weekday   0   1   2   3   4   5   6
# promo
# 0        21  22  23  23  20  20  21
# 1        73  72  71  71  74  74  73
# 33 promo weekday The P-Value of the ChiSq Test is: 0.9966101430769535
# bolOpen   0    1
# promo
# 0        18  132
# 1        80  428
# 33 promo bolOpen The P-Value of the ChiSq Test is: 0.3161586950252727
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        83   1   3   2   1   5   3
# 1        11  93  91  92  93  89  91
# 33 bolOpen weekday The P-Value of the ChiSq Test is: 9.999462363114776e-98
# promo         0    1
# bolHoliday
# 0           134  414
# 1            16   94
# 33 bolHoliday promo The P-Value of the ChiSq Test is: 0.03269639791258489
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  91  92  92  89  90
# 1           88   6   3   2   2   5   4
# 33 bolHoliday weekday The P-Value of the ChiSq Test is: 1.1744439152316264e-97
# bolOpen      0    1
# bolHoliday
# 0            2  546
# 1           96   14
# 33 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.032463189882357e-119
# 34 promo P-Value for Anova is:  0.5226148239182352
# 34 weekday P-Value for Anova is:  2.1913908800705504e-18
# 34 bolOpen P-Value for Anova is:  2.7100476539134513e-24
# 34 bolHoliday P-Value for Anova is:  9.679948854852549e-26
# weekday   0   1   2   3   4   5   6
# promo
# 0        21  22  23  23  20  20  21
# 1        73  72  71  71  74  74  73
# 34 promo weekday The P-Value of the ChiSq Test is: 0.9966101430769535
# bolOpen   0    1
# promo
# 0        16  134
# 1        87  421
# 34 promo bolOpen The P-Value of the ChiSq Test is: 0.07424226322598733
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   4   1   3   1   6   3
# 1         9  90  93  91  93  88  91
# 34 bolOpen weekday The P-Value of the ChiSq Test is: 1.9189480866985953e-97
# promo         0    1
# bolHoliday
# 0           135  415
# 1            15   93
# 34 bolHoliday promo The P-Value of the ChiSq Test is: 0.022134500709257352
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  89  92  91  93  88  90
# 1           87   5   2   3   1   6   4
# 34 bolHoliday weekday The P-Value of the ChiSq Test is: 3.2557551920812554e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           100    8
# 34 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.7318154159327416e-126
# 35 promo P-Value for Anova is:  0.6871707909928109
# 35 weekday P-Value for Anova is:  1.307369446708284e-12
# 35 bolOpen P-Value for Anova is:  7.390062727162184e-15
# 35 bolHoliday P-Value for Anova is:  3.2716830212044235e-16
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 35 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        38  363
# 1        33  224
# 35 promo bolOpen The P-Value of the ChiSq Test is: 0.21936147614122078
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   3   1
# 1        35  91  92  92  93  91  93
# 35 bolOpen weekday The P-Value of the ChiSq Test is: 1.4197753646033676e-63
# promo         0    1
# bolHoliday
# 0           342  209
# 1            59   48
# 35 bolHoliday promo The P-Value of the ChiSq Test is: 0.2164441517646767
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  89  92
# 1           88   7   2   2   1   5   2
# 35 bolHoliday weekday The P-Value of the ChiSq Test is: 2.3304145183459556e-101
# bolOpen      0    1
# bolHoliday
# 0            2  549
# 1           69   38
# 35 bolHoliday bolOpen The P-Value of the ChiSq Test is: 8.802234505173199e-84
# 36 promo P-Value for Anova is:  0.00047486370706067933
# 36 weekday P-Value for Anova is:  2.8328801745544115e-15
# 36 bolOpen P-Value for Anova is:  1.5669248882908459e-21
# 36 bolHoliday P-Value for Anova is:  2.1452641500566922e-20
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 36 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        65  296
# 1        41  256
# 36 promo bolOpen The P-Value of the ChiSq Test is: 0.17633703703875006
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        90   5   2   2   1   4   2
# 1         4  89  92  92  93  90  92
# 36 bolOpen weekday The P-Value of the ChiSq Test is: 3.8131490104066284e-108
# promo         0    1
# bolHoliday
# 0           296  257
# 1            65   40
# 36 bolHoliday promo The P-Value of the ChiSq Test is: 0.14029936125796608
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  92  92  93  90  91
# 1           87   6   2   2   1   4   3
# 36 bolHoliday weekday The P-Value of the ChiSq Test is: 1.0264911765858248e-100
# bolOpen       0    1
# bolHoliday
# 0             3  550
# 1           103    2
# ...
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 39 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        45  316
# 1        26  271
# 39 promo bolOpen The P-Value of the ChiSq Test is: 0.16132249060163972
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        59   3   2   2   1   3   1
# 1        35  91  92  92  93  91  93
# 39 bolOpen weekday The P-Value of the ChiSq Test is: 1.4197753646033676e-63
# promo         0    1
# bolHoliday
# 0           297  255
# 1            64   42
# 39 bolHoliday promo The P-Value of the ChiSq Test is: 0.2546951755239689
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  89  91  91  93  90  92
# 1           88   5   3   3   1   4   2
# 39 bolHoliday weekday The P-Value of the ChiSq Test is: 2.8100025986200162e-102
# bolOpen      0    1
# bolHoliday
# 0            2  550
# 1           69   37
# 39 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.0207706142350735e-84
# 40 promo P-Value for Anova is:  0.31875894347075606
# 40 weekday P-Value for Anova is:  4.756746857131774e-32
# 40 bolOpen P-Value for Anova is:  4.419185955564729e-36
# 40 bolHoliday P-Value for Anova is:  3.369243461177242e-35
# weekday   0   1   2   3   4   5   6
# promo
# 0        47  48  46  46  45  47  47
# 1        47  46  48  48  49  47  47
# 40 promo weekday The P-Value of the ChiSq Test is: 0.9997264315844906
# bolOpen   0    1
# promo
# 0        52  274
# 1        53  279
# 40 promo bolOpen The P-Value of the ChiSq Test is: 0.9188147673931524
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        89   5   2   2   1   5   1
# 1         5  89  92  92  93  89  93
# 40 bolOpen weekday The P-Value of the ChiSq Test is: 1.4716538428470416e-106
# promo         0    1
# bolHoliday
# 0           272  278
# 1            54   54
# 40 bolHoliday promo The P-Value of the ChiSq Test is: 0.9987237029569834
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  88  92
# 1           88   7   2   2   1   6   2
# 40 bolHoliday weekday The P-Value of the ChiSq Test is: 2.9785078141445735e-100
# bolOpen       0    1
# bolHoliday
# 0             2  548
# 1           103    5
# 40 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.2897090329570751e-132
# 41 promo P-Value for Anova is:  0.6217132659086675
# 41 weekday P-Value for Anova is:  1.5138343017076906e-22
# 41 bolOpen P-Value for Anova is:  3.112930629822253e-24
# 41 bolHoliday P-Value for Anova is:  1.5294374639857068e-23
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 41 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        49  352
# 1        33  224
# 41 promo bolOpen The P-Value of the ChiSq Test is: 0.9089644699416238
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        70   3   2   2   1   3   1
# 1        24  91  92  92  93  91  93
# 41 bolOpen weekday The P-Value of the ChiSq Test is: 1.83111540260858e-80
# promo         0    1
# bolHoliday
# 0           344  209
# 1            57   48
# 41 bolHoliday promo The P-Value of the ChiSq Test is: 0.15679306461227663
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  92  92  93  90  91
# 1           87   6   2   2   1   4   3
# 41 bolHoliday weekday The P-Value of the ChiSq Test is: 1.0264911765858248e-100
# bolOpen      0    1
# bolHoliday
# 0            3  550
# 1           79   26
# 41 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.1303334496506905e-98
# 42 promo P-Value for Anova is:  0.0006922077339642583
# 42 weekday P-Value for Anova is:  9.134101962610232e-19
# 42 bolOpen P-Value for Anova is:  4.4748603129734124e-24
# 42 bolHoliday P-Value for Anova is:  5.514844936219715e-24
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  51  50  50  51  53  53
# 1        41  43  44  44  43  41  41
# 42 promo weekday The P-Value of the ChiSq Test is: 0.9977988392572147
# bolOpen   0    1
# promo
# 0        62  299
# 1        40  257
# 42 promo bolOpen The P-Value of the ChiSq Test is: 0.23050434049314744
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        89   4   2   2   1   3   1
# 1         5  90  92  92  93  91  93
# 42 bolOpen weekday The P-Value of the ChiSq Test is: 2.757804202366434e-110
# promo         0    1
# bolHoliday
# 0           296  257
# 1            65   40
# 42 bolHoliday promo The P-Value of the ChiSq Test is: 0.14029936125796608
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  92  92  93  90  91
# 1           87   6   2   2   1   4   3
# 42 bolHoliday weekday The P-Value of the ChiSq Test is: 1.0264911765858248e-100
# bolOpen      0    1
# bolHoliday
# 0            3  550
# 1           99    6
# 42 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.2281194201123404e-129
# 43 promo P-Value for Anova is:  3.087700993384692e-07
# 43 weekday P-Value for Anova is:  2.35040435920127e-19
# 43 bolOpen P-Value for Anova is:  6.248499164044099e-25
# 43 bolHoliday P-Value for Anova is:  2.0196324266189027e-26
# weekday   0   1   2   3   4   5   6
# promo
# 0        76  74  73  73  75  76  76
# 1        18  20  21  21  19  18  18
# 43 promo weekday The P-Value of the ChiSq Test is: 0.9934546411020053
# bolOpen   0    1
# promo
# 0        84  439
# 1        19  116
# 43 promo bolOpen The P-Value of the ChiSq Test is: 0.6645462137815579
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   6   1   3   1   4   3
# 1         9  88  93  91  93  90  91
# 43 bolOpen weekday The P-Value of the ChiSq Test is: 1.9189480866985953e-97
# promo         0    1
# bolHoliday
# 0           434  116
# 1            89   19
# 43 bolHoliday promo The P-Value of the ChiSq Test is: 0.4884511659259563
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  87  92  91  93  90  90
# 1           87   7   2   3   1   4   4
# 43 bolHoliday weekday The P-Value of the ChiSq Test is: 2.791749974823376e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           100    8
# 43 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.7318154159327416e-126
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:3347: RuntimeWarning:
#
# invalid value encountered in double_scalars
# 44 promo P-Value for Anova is:  nan
# 44 weekday P-Value for Anova is:  3.2098733979411234e-19
# 44 bolOpen P-Value for Anova is:  1.474970796310664e-23
# 44 bolHoliday P-Value for Anova is:  2.2038295059691008e-23
# weekday   0   1   2   3   4   5   6
# promo
# 0        94  94  94  94  94  94  94
# 44 promo weekday The P-Value of the ChiSq Test is: 1.0
# bolOpen    0    1
# promo
# 0        103  555
# 44 promo bolOpen The P-Value of the ChiSq Test is: 1.0
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   4   1   3   1   6   3
# 1         9  90  93  91  93  88  91
# 44 bolOpen weekday The P-Value of the ChiSq Test is: 1.9189480866985953e-97
# promo         0
# bolHoliday
# 0           550
# 1           108
# 44 bolHoliday promo The P-Value of the ChiSq Test is: 1.0
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  89  92  91  93  88  90
# 1           87   5   2   3   1   6   4
# 44 bolHoliday weekday The P-Value of the ChiSq Test is: 3.2557551920812554e-97
# bolOpen       0    1
# bolHoliday
# 0             3  547
# 1           100    8
# 44 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.7318154159327416e-126
# 45 promo P-Value for Anova is:  0.2339723682784035
# 45 weekday P-Value for Anova is:  6.132168488631294e-22
# 45 bolOpen P-Value for Anova is:  7.449623061813572e-29
# 45 bolHoliday P-Value for Anova is:  5.660002981060425e-27
# weekday   0   1   2   3   4   5   6
# promo
# 0        21  22  23  23  20  20  21
# 1        73  72  71  71  74  74  73
# 45 promo weekday The P-Value of the ChiSq Test is: 0.9966101430769535
# bolOpen   0    1
# promo
# 0        17  133
# 1        88  420
# 45 promo bolOpen The P-Value of the ChiSq Test is: 0.10243303656070991
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        89   5   2   2   1   5   1
# 1         5  89  92  92  93  89  93
# 45 bolOpen weekday The P-Value of the ChiSq Test is: 1.4716538428470416e-106
# promo         0    1
# bolHoliday
# 0           135  415
# 1            15   93
# 45 bolHoliday promo The P-Value of the ChiSq Test is: 0.022134500709257352
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  92  92  93  88  92
# 1           88   7   2   2   1   6   2
# 45 bolHoliday weekday The P-Value of the ChiSq Test is: 2.9785078141445735e-100
# bolOpen       0    1
# bolHoliday
# 0             2  548
# 1           103    5
# 45 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.2897090329570751e-132
# 46 promo P-Value for Anova is:  0.0032690046500650173
# 46 weekday P-Value for Anova is:  5.055764277125837e-20
# 46 bolOpen P-Value for Anova is:  1.6907661840310744e-21
# 46 bolHoliday P-Value for Anova is:  7.360656345356664e-23
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 46 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        50  334
# 1        44  230
# 46 promo bolOpen The P-Value of the ChiSq Test is: 0.3247799981512887
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        81   2   2   2   0   6   1
# 1        13  92  92  92  94  88  93
# 46 bolOpen weekday The P-Value of the ChiSq Test is: 3.522290329546757e-97
# promo         0    1
# bolHoliday
# 0           330  219
# 1            54   55
# 46 bolHoliday promo The P-Value of the ChiSq Test is: 0.05261884180596141
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  87  91  92  93  88  92
# 1           88   7   3   2   1   6   2
# 46 bolHoliday weekday The P-Value of the ChiSq Test is: 4.622213240979697e-99
# bolOpen      0    1
# bolHoliday
# 0            2  547
# 1           92   17
# 46 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.3361556267492269e-114
# 47 promo P-Value for Anova is:  1.7981155271445397e-20
# 47 weekday P-Value for Anova is:  1.2939498632549822e-18
# 47 bolOpen P-Value for Anova is:  1.1180655943841502e-22
# 47 bolHoliday P-Value for Anova is:  1.6740730860895686e-24
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 47 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        51  333
# 1        47  227
# 47 promo bolOpen The P-Value of the ChiSq Test is: 0.20615716670888382
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        85   1   3   3   0   4   2
# 1         9  93  91  91  94  90  92
# 47 bolOpen weekday The P-Value of the ChiSq Test is: 1.2820541207910169e-103
# promo         0    1
# bolHoliday
# 0           330  220
# 1            54   54
# 47 bolHoliday promo The P-Value of the ChiSq Test is: 0.06866477429895995
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  91  91  93  90  91
# 1           88   6   3   3   1   4   3
# 47 bolHoliday weekday The P-Value of the ChiSq Test is: 5.950574969998988e-100
# bolOpen      0    1
# bolHoliday
# 0            2  548
# 1           96   12
# 47 bolHoliday bolOpen The P-Value of the ChiSq Test is: 7.026130725383532e-122
# 48 promo P-Value for Anova is:  7.779574885473526e-07
# 48 weekday P-Value for Anova is:  2.1391454621301673e-18
# 48 bolOpen P-Value for Anova is:  4.722014293652015e-22
# 48 bolHoliday P-Value for Anova is:  1.2273404477825819e-23
# weekday   0   1   2   3   4   5   6
# promo
# 0        53  55  53  52  51  52  53
# 1        41  39  41  42  43  42  41
# 48 promo weekday The P-Value of the ChiSq Test is: 0.9987913111676995
# bolOpen   0    1
# promo
# 0        54  315
# 1        44  245
# 48 promo bolOpen The P-Value of the ChiSq Test is: 0.9196078705257025
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        83   1   3   2   1   5   3
# 1        11  93  91  92  93  89  91
# 48 bolOpen weekday The P-Value of the ChiSq Test is: 9.999462363114776e-98
# promo         0    1
# bolHoliday
# 0           310  238
# 1            59   51
# 48 bolHoliday promo The P-Value of the ChiSq Test is: 0.6452369710906168
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  91  92  92  89  90
# 1           88   6   3   2   2   5   4
# 48 bolHoliday weekday The P-Value of the ChiSq Test is: 1.1744439152316264e-97
# bolOpen      0    1
# bolHoliday
# 0            2  546
# 1           96   14
# 48 bolHoliday bolOpen The P-Value of the ChiSq Test is: 3.032463189882357e-119
# 49 promo P-Value for Anova is:  0.013785505389649969
# 49 weekday P-Value for Anova is:  3.83964267516831e-13
# 49 bolOpen P-Value for Anova is:  3.3218862029199694e-16
# 49 bolHoliday P-Value for Anova is:  1.2999393095302656e-17
# weekday   0   1   2   3   4   5   6
# promo
# 0        54  56  56  57  54  53  54
# 1        40  38  38  37  40  41  40
# 49 promo weekday The P-Value of the ChiSq Test is: 0.9969876259484729
# bolOpen   0    1
# promo
# 0        51  333
# 1        48  226
# 49 promo bolOpen The P-Value of the ChiSq Test is: 0.16513318277005676
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        86   1   3   2   2   4   1
# 1         8  93  91  92  92  90  93
# 49 bolOpen weekday The P-Value of the ChiSq Test is: 3.204432703436084e-105
# promo         0    1
# bolHoliday
# 0           330  219
# 1            54   55
# 49 bolHoliday promo The P-Value of the ChiSq Test is: 0.05261884180596141
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            6  88  91  92  91  90  91
# 1           88   6   3   2   3   4   3
# 49 bolHoliday weekday The P-Value of the ChiSq Test is: 9.915435056996789e-99
# bolOpen      0    1
# bolHoliday
# 0            2  547
# 1           97   12
# 49 bolHoliday bolOpen The P-Value of the ChiSq Test is: 4.738810541085556e-122
# 50 promo P-Value for Anova is:  0.0624278705254822
# 50 weekday P-Value for Anova is:  6.292562849475544e-16
# 50 bolOpen P-Value for Anova is:  2.2047147129495295e-20
# 50 bolHoliday P-Value for Anova is:  6.37186779743137e-19
# weekday   0   1   2   3   4   5   6
# promo
# 0        56  58  58  60  57  56  56
# 1        38  36  36  34  37  38  38
# 50 promo weekday The P-Value of the ChiSq Test is: 0.9963976271454764
# bolOpen   0    1
# promo
# 0        60  341
# 1        46  211
# 50 promo bolOpen The P-Value of the ChiSq Test is: 0.3729787316950428
# weekday   0   1   2   3   4   5   6
# bolOpen
# 0        90   5   2   2   1   4   2
# 1         4  89  92  92  93  90  92
# 50 bolOpen weekday The P-Value of the ChiSq Test is: 3.8131490104066284e-108
# promo         0    1
# bolHoliday
# 0           344  209
# 1            57   48
# 50 bolHoliday promo The P-Value of the ChiSq Test is: 0.15679306461227663
# weekday      0   1   2   3   4   5   6
# bolHoliday
# 0            7  88  92  92  93  90  91
# 1           87   6   2   2   1   4   3
# 50 bolHoliday weekday The P-Value of the ChiSq Test is: 1.0264911765858248e-100
# bolOpen       0    1
# bolHoliday
# 0             3  550
# 1           103    2
# 50 bolHoliday bolOpen The P-Value of the ChiSq Test is: 1.3606389235983703e-135

# %%
results_chisq.head()
# Out:
#   sku                 prueba        pValue
# 0   1       promo vs weekday  9.969876e-01
# 1   1       promo vs bolOpen  9.770313e-02
# 2   1     bolOpen vs weekday  1.918948e-97
# 3   1    bolHoliday vs promo  4.193925e-02
# 4   1  bolHoliday vs weekday  3.255755e-97

# %%
results_corr.to_csv('tablas_correlaciones_por_sku.csv', index=False)

# %%
results_anova.to_csv('resultados_anova_por_sku.csv', index=False)

# %%
results_chisq.to_csv('resultados_chisq_por_sku.csv', index=False)

# %%
res = results_chisq[results_chisq["sku"]=="3"].append(results_anova[results_anova["sku"]=="3"])

# %%
print(tabulate(res.set_index("sku"), headers=res.columns, tablefmt='latex'))
# Out:
# \begin{tabular}{rlr}
# \hline
#    sku & prueba                  &       pValue \\
# \hline
#      3 & promo vs weekday        & 0.996988     \\
#      3 & promo vs bolOpen        & 0.206157     \\
#      3 & bolOpen vs weekday      & 9.99946e-98  \\
#      3 & bolHoliday vs promo     & 0.0399127    \\
#      3 & bolHoliday vs weekday   & 1.17444e-97  \\
#      3 & bolHoliday vs bolOpen   & 3.03246e-119 \\
#      3 & promo vs udsVentaT      & 0.12388      \\
#      3 & weekday vs udsVentaT    & 7.92651e-24  \\
#      3 & bolOpen vs udsVentaT    & 5.22379e-25  \\
#      3 & bolHoliday vs udsVentaT & 4.67007e-26  \\
# \hline
# \end{tabular}

# %%
res = results_chisq[results_chisq["sku"]=="1"].append(results_anova[results_anova["sku"]=="1"])
print(tabulate(res.set_index("sku"), headers=res.columns, tablefmt='latex'))
# Out:
# \begin{tabular}{rlr}
# \hline
#    sku & prueba                  &       pValue \\
# \hline
#      1 & promo vs weekday        & 0.996988     \\
#      1 & promo vs bolOpen        & 0.0977031    \\
#      1 & bolOpen vs weekday      & 1.91895e-97  \\
#      1 & bolHoliday vs promo     & 0.0419392    \\
#      1 & bolHoliday vs weekday   & 3.25576e-97  \\
#      1 & bolHoliday vs bolOpen   & 1.73182e-126 \\
#      1 & promo vs udsVentaT      & 0.8994       \\
#      1 & weekday vs udsVentaT    & 9.15099e-33  \\
#      1 & bolOpen vs udsVentaT    & 3.78395e-41  \\
#      1 & bolHoliday vs udsVentaT & 5.42343e-43  \\
# \hline
# \end{tabular}
